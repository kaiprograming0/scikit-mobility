# %% [markdown]
# # scikit-mobility
# ### scikit-mobilityは位置情報を可視化するツールで、人の動きについて解析することができる。

# %%
import skmob
import warnings
warnings.filterwarnings('ignore')

# %%
tdf = skmob.TrajDataFrame.from_file('geolife_sample.txt.gz', latitude='lat', longitude='lon', user_id='user', datetime='datetime')
tdf.head()
# Out:
#          lat         lng            datetime  uid
# 0  39.984094  116.319236 2008-10-23 05:53:05    1
# 1  39.984198  116.319322 2008-10-23 05:53:06    1
# 2  39.984224  116.319402 2008-10-23 05:53:11    1
# 3  39.984211  116.319389 2008-10-23 05:53:16    1
# 4  39.984217  116.319422 2008-10-23 05:53:21    1

# %%
tdf.plot_trajectory(zoom=10, weight=3, opacity=0.9, tiles='OpenStreetMap')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_becfe2b80675ba9e1c20cedef8a2088d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_becfe2b80675ba9e1c20cedef8a2088d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_becfe2b80675ba9e1c20cedef8a2088d = L.map(
#                 &quot;map_becfe2b80675ba9e1c20cedef8a2088d&quot;,
#                 {
#                     center: [39.9962335, 116.32167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_becfe2b80675ba9e1c20cedef8a2088d);
#
#
#
#
#
#             var tile_layer_b49810ea4363217a5d217e2e6cd3bf88 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_becfe2b80675ba9e1c20cedef8a2088d);
#
#
#         function geo_json_91ea2a5667c673473d82ae74fa1be801_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FF71FD&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_91ea2a5667c673473d82ae74fa1be801_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_91ea2a5667c673473d82ae74fa1be801 = L.geoJson(null, {
#                 onEachFeature: geo_json_91ea2a5667c673473d82ae74fa1be801_onEachFeature,
#
#                 style: geo_json_91ea2a5667c673473d82ae74fa1be801_styler,
#         });
#
#         function geo_json_91ea2a5667c673473d82ae74fa1be801_add (data) {
#             geo_json_91ea2a5667c673473d82ae74fa1be801
#                 .addData(data)
#                 .addTo(map_becfe2b80675ba9e1c20cedef8a2088d);
#         }
#             geo_json_91ea2a5667c673473d82ae74fa1be801_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[116.319236, 39.984094], [116.324395, 39.979764], [116.326728, 39.984062], [116.326543, 39.993742], [116.32167, 40.001626], [116.31591, 40.009559], [116.310135, 40.016448], [116.305591, 40.014572], [116.306529, 40.01382], [116.306526, 40.013859], [116.31256, 40.010884], [116.320113, 40.004924], [116.32627, 39.997362], [116.326817, 39.98674], [116.325772, 39.978983], [116.324616, 39.979582], [116.310814, 39.980075], [116.308814, 39.981103], [116.310729, 39.981595], [116.313583, 39.979542], [116.313722, 39.979553], [116.327028, 39.979859], [116.326168, 39.978777], [116.325387, 39.979729], [116.310938, 39.980088], [116.310485, 39.981422], [116.310913, 39.981931], [116.312635, 39.979568], [116.323849, 39.979524], [116.30576, 40.015904], [116.310613, 40.015327], [116.311899, 40.013635], [116.309028, 40.003765], [116.309026, 39.998026], [116.300121, 39.996491], [116.291189, 39.99598], [116.280083, 39.997194], [116.267794, 40.002691], [116.250253, 40.004855], [116.236305, 39.999345], [116.220385, 39.995421], [116.213343, 39.992248], [116.207124, 39.992479], [116.201177, 39.993741], [116.198934, 39.997028], [116.196825, 39.996838], [116.196669, 39.997212], [116.195698, 39.999913], [116.192199, 40.002138], [116.189877, 40.005311], [116.185017, 40.004414], [116.18101, 40.002771], [116.175774, 40.002766], [116.172672, 40.000699], [116.171119, 40.001718], [116.170751, 40.002577], [116.169433, 40.002429], [116.167575, 40.002232], [116.166736, 40.00174], [116.165926, 40.000155], [116.16209, 39.999291], [116.156125, 39.998647], [116.15132, 39.997193], [116.14741, 39.993966], [116.145321, 39.993154], [116.147363, 39.993923], [116.152825, 39.997664], [116.157881, 39.997812], [116.161717, 39.995573], [116.167572, 39.995071], [116.169461, 39.994648], [116.173318, 39.996042], [116.176718, 39.996848], [116.179708, 39.99684], [116.184516, 39.995428], [116.187584, 39.992407], [116.187005, 39.989942], [116.186206, 39.989155], [116.18821, 39.988959], [116.188529, 39.988176], [116.191276, 39.98977], [116.193994, 39.99103], [116.197219, 39.991895], [116.203145, 39.99146], [116.204994, 39.992475], [116.215251, 39.991429], [116.246945, 40.004265], [116.262046, 40.004073], [116.275639, 40.00045], [116.285521, 39.996866], [116.294892, 39.996003], [116.308795, 39.998014], [116.309348, 40.003968], [116.312223, 40.013299], [116.305672, 40.014134], [116.311501, 40.017163], [116.307487, 40.026715], [116.314128, 40.031998], [116.305672, 40.0437], [116.297114, 40.057642], [116.31043, 40.069592], [116.329794, 40.069405], [116.338666, 40.071323], [116.342078, 40.075335], [116.339464, 40.074122], [116.336552, 40.069872], [116.330634, 40.069676], [116.330137, 40.069522], [116.312949, 40.069538], [116.296869, 40.057774], [116.305267, 40.04412], [116.31408, 40.031764], [116.321623, 40.015654], [116.331197, 40.001672], [116.3315, 39.987848], [116.333701, 39.974835], [116.383644, 39.977135], [116.384162, 39.977667], [116.384126, 39.977643], [116.384335, 39.977701], [116.384152, 39.977661], [116.384116, 39.977628], [116.385786, 39.975634],

# %% [markdown]
# # フィルター機能で適切な可視化
# ### filteringを用いる
# ### max_speed_kmが５(km/h)から上の図と比較すると下の線が短くなっていることが分かる

# %%
from skmob.preprocessing import filtering
filtered_tdf = filtering.filter(tdf, max_speed_kmh=5)
filtered_tdf.plot_trajectory(zoom=10, weight=3, opacity=0.9, tiles='OpenStreetMap')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9ce7c886fe7b876910a023a74bac28d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9ce7c886fe7b876910a023a74bac28d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9ce7c886fe7b876910a023a74bac28d = L.map(
#                 &quot;map_e9ce7c886fe7b876910a023a74bac28d&quot;,
#                 {
#                     center: [40.013152, 116.306602],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e9ce7c886fe7b876910a023a74bac28d);
#
#
#
#
#
#             var tile_layer_1c00d9fc7abef24c5f83a12704e3725c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9ce7c886fe7b876910a023a74bac28d);
#
#
#         function geo_json_990b35a8ad77d10245e2903398d9562f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFDC3D&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_990b35a8ad77d10245e2903398d9562f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_990b35a8ad77d10245e2903398d9562f = L.geoJson(null, {
#                 onEachFeature: geo_json_990b35a8ad77d10245e2903398d9562f_onEachFeature,
#
#                 style: geo_json_990b35a8ad77d10245e2903398d9562f_styler,
#         });
#
#         function geo_json_990b35a8ad77d10245e2903398d9562f_add (data) {
#             geo_json_990b35a8ad77d10245e2903398d9562f
#                 .addData(data)
#                 .addTo(map_e9ce7c886fe7b876910a023a74bac28d);
#         }
#             geo_json_990b35a8ad77d10245e2903398d9562f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[116.319236, 39.984094], [116.306545, 40.01383], [116.306544, 40.013833], [116.306535, 40.013823], [116.30653, 40.013821], [116.306528, 40.013814], [116.306531, 40.013809], [116.306532, 40.013806], [116.306526, 40.013864], [116.326845, 39.978484], [116.310198, 39.981373], [116.313061, 39.979586], [116.313168, 39.979572], [116.313671, 39.979657], [116.31375, 39.979596], [116.313584, 39.979513], [116.313655, 39.979603], [116.313848, 39.979605], [116.326254, 39.977759], [116.326772, 39.977985], [116.309689, 39.981736], [116.310857, 39.981687], [116.310919, 39.981897], [116.310937, 39.981887], [116.310844, 39.979709], [116.305855, 40.015941], [116.306765, 40.016048], [116.310448, 40.015361], [116.311388, 40.014721], [116.311413, 40.014998], [116.196795, 39.99694], [116.196292, 39.997324], [116.196273, 39.997704], [116.195872, 39.998261], [116.195662, 39.999744], [116.194779, 40.000849], [116.193933, 40.001159], [116.192802, 40.001636], [116.192129, 40.002179], [116.191795, 40.002446], [116.190793, 40.003418], [116.19004, 40.005068], [116.189426, 40.005573], [116.188191, 40.005545], [116.185148, 40.004449], [116.182373, 40.003923], [116.180191, 40.003556], [116.180751, 40.002816], [116.179115, 40.003211], [116.17797, 40.003659], [116.176614, 40.002987], [116.175751, 40.002755], [116.173991, 40.000501], [116.172457, 40.000791], [116.171902, 40.000988], [116.171519, 40.001299], [116.171411, 40.001332], [116.170967, 40.001866], [116.170863, 40.002005], [116.170797, 40.002163], [116.170786, 40.002273], [116.170686, 40.002656], [116.170656, 40.002702], [116.170508, 40.002636], [116.169655, 40.002567], [116.169361, 40.00246], [116.169138, 40.002523], [116.168901, 40.002622], [116.168096, 40.002316], [116.167184, 40.002004], [116.16696, 40.001868], [116.166958, 40.001868], [116.166869, 40.001826], [116.166707, 40.001664], [116.166459, 40.00087], [116.16593, 40.00016], [116.165938, 40.000154], [116.164005, 39.998855], [116.161907, 39.999356], [116.15955, 39.999536], [116.158417, 39.999117], [116.154644, 39.998394], [116.153132, 39.997692], [116.152323, 39.997321], [116.151319, 39.997193], [116.151082, 39.997006], [116.147421, 39.993969], [116.14678, 39.993263], [116.146103, 39.993066], [116.145859, 39.993016], [116.145463, 39.993325], [116.14551, 39.993219], [116.145409, 39.992602], [116.151001, 39.99701], [116.155351, 39.998343], [116.157807, 39.997798], [116.159889, 39.997557], [116.161961, 39.995575], [116.166315, 39.995438], [116.167827, 39.994629], [116.167663, 39.994346], [116.16747, 39.993779], [116.170026, 39.994948], [116.171066, 39.995461], [116.171362, 39.995517], [116.174109, 39.996007], [116.176062, 39.996641], [116.175722, 39.996352], [116.176719, 39.99685], [116.177778, 39.997051], [116.177974, 39.996547], [116.179798, 39.996858], [116.183134, 39.995821], [116.184578, 39.995481], [116.187159, 39.993892], [116.18737, 39.992731], [116.188093, 39.991602], [116.18821, 39.991059], [116.188565, 39.990506], [116.187272, 39.990088], [116.186617, 39.989713], [116.186215, 39.989817], [116.186314, 39.9

# %% [markdown]
# # 滞在検出機能を用いてプロット
# ### detectionを用いる
# ### stop_radius_factorとspatial_radius_kmに指定した時間(minutes_for_a_stop分間)いた人をプロットすることができる

# %%
import skmob
from skmob.preprocessing import detection
import pandas as pd

url = skmob.utils.constants.GEOLIFE_SAMPLE
df = pd.read_csv(url, sep=',', compression='gzip')
tdf = skmob.TrajDataFrame(df, latitude='lat', longitude='lon', user_id='user', datetime='datetime')

stdf = detection.stay_locations(tdf, stop_radius_factor=0.5, minutes_for_a_stop=60, spatial_radius_km=0.2, leaving_time=True)

map_f = tdf.plot_trajectory(max_points=1000, start_end_markers=False)
stdf.plot_stops(map_f=map_f)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9eef9ffedcfbd3a573f9d7c3c23bc58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9eef9ffedcfbd3a573f9d7c3c23bc58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9eef9ffedcfbd3a573f9d7c3c23bc58 = L.map(
#                 &quot;map_f9eef9ffedcfbd3a573f9d7c3c23bc58&quot;,
#                 {
#                     center: [39.9962335, 116.32167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f9eef9ffedcfbd3a573f9d7c3c23bc58);
#
#
#
#
#
#             var tile_layer_2a46a2463949e2883e097f54627b18f4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9eef9ffedcfbd3a573f9d7c3c23bc58);
#
#
#         function geo_json_59d38905bacd9083dff6309bed21f5ba_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FFDC3D&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.75, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_59d38905bacd9083dff6309bed21f5ba_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_59d38905bacd9083dff6309bed21f5ba = L.geoJson(null, {
#                 onEachFeature: geo_json_59d38905bacd9083dff6309bed21f5ba_onEachFeature,
#
#                 style: geo_json_59d38905bacd9083dff6309bed21f5ba_styler,
#         });
#
#         function geo_json_59d38905bacd9083dff6309bed21f5ba_add (data) {
#             geo_json_59d38905bacd9083dff6309bed21f5ba
#                 .addData(data)
#                 .addTo(map_f9eef9ffedcfbd3a573f9d7c3c23bc58);
#         }
#             geo_json_59d38905bacd9083dff6309bed21f5ba_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[116.319236, 39.984094], [116.324395, 39.979764], [116.326728, 39.984062], [116.326543, 39.993742], [116.32167, 40.001626], [116.31591, 40.009559], [116.310135, 40.016448], [116.305591, 40.014572], [116.306529, 40.01382], [116.306526, 40.013859], [116.31256, 40.010884], [116.320113, 40.004924], [116.32627, 39.997362], [116.326817, 39.98674], [116.325772, 39.978983], [116.324616, 39.979582], [116.310814, 39.980075], [116.308814, 39.981103], [116.310729, 39.981595], [116.313583, 39.979542], [116.313722, 39.979553], [116.327028, 39.979859], [116.326168, 39.978777], [116.325387, 39.979729], [116.310938, 39.980088], [116.310485, 39.981422], [116.310913, 39.981931], [116.312635, 39.979568], [116.323849, 39.979524], [116.30576, 40.015904], [116.310613, 40.015327], [116.311899, 40.013635], [116.309028, 40.003765], [116.309026, 39.998026], [116.300121, 39.996491], [116.291189, 39.99598], [116.280083, 39.997194], [116.267794, 40.002691], [116.250253, 40.004855], [116.236305, 39.999345], [116.220385, 39.995421], [116.213343, 39.992248], [116.207124, 39.992479], [116.201177, 39.993741], [116.198934, 39.997028], [116.196825, 39.996838], [116.196669, 39.997212], [116.195698, 39.999913], [116.192199, 40.002138], [116.189877, 40.005311], [116.185017, 40.004414], [116.18101, 40.002771], [116.175774, 40.002766], [116.172672, 40.000699], [116.171119, 40.001718], [116.170751, 40.002577], [116.169433, 40.002429], [116.167575, 40.002232], [116.166736, 40.00174], [116.165926, 40.000155], [116.16209, 39.999291], [116.156125, 39.998647], [116.15132, 39.997193], [116.14741, 39.993966], [116.145321, 39.993154], [116.147363, 39.993923], [116.152825, 39.997664], [116.157881, 39.997812], [116.161717, 39.995573], [116.167572, 39.995071], [116.169461, 39.994648], [116.173318, 39.996042], [116.176718, 39.996848], [116.179708, 39.99684], [116.184516, 39.995428], [116.187584, 39.992407], [116.187005, 39.989942], [116.186206, 39.989155], [116.18821, 39.988959], [116.188529, 39.988176], [116.191276, 39.98977], [116.193994, 39.99103], [116.197219, 39.991895], [116.203145, 39.99146], [116.204994, 39.992475], [116.215251, 39.991429], [116.246945, 40.004265], [116.262046, 40.004073], [116.275639, 40.00045], [116.285521, 39.996866], [116.294892, 39.996003], [116.308795, 39.998014], [116.309348, 40.003968], [116.312223, 40.013299], [116.305672, 40.014134], [116.311501, 40.017163], [116.307487, 40.026715], [116.314128, 40.031998], [116.305672, 40.0437], [116.297114, 40.057642], [116.31043, 40.069592], [116.329794, 40.069405], [116.338666, 40.071323], [116.342078, 40.075335], [116.339464, 40.074122], [116.336552, 40.069872], [116.330634, 40.069676], [116.330137, 40.069522], [116.312949, 40.069538], [116.296869, 40.057774], [116.305267, 40.04412], [116.31408, 40.

# %% [markdown]
# ## FlowDataFrameを使うと下記の地図を出力することも可能。

# %%
import skmob
import geopandas as gpd
# load a spatial tessellation
url_tess = skmob.utils.constants.NY_COUNTIES_2011
tessellation = gpd.read_file(url_tess).rename(columns={'tile_id': 'tile_ID'})
# load real flows into a FlowDataFrame
# download the file with the real fluxes from: https://raw.githubusercontent.com/scikit-mobility/scikit-mobility/master/tutorial/data/NY_commuting_flows_2011.csv
fdf = skmob.FlowDataFrame.from_file("NY_commuting_flows_2011.csv",
                                        tessellation=tessellation,
                                        tile_id='tile_ID',
                                        sep=",")
m = fdf.plot_flows(flow_color='purple', tiles='OpenStreetMap')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e57dbf1d6062c912a9ea80cd604048ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e57dbf1d6062c912a9ea80cd604048ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e57dbf1d6062c912a9ea80cd604048ab = L.map(
#                 &quot;map_e57dbf1d6062c912a9ea80cd604048ab&quot;,
#                 {
#                     center: [42.555968337076926, -75.47699722292556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e57dbf1d6062c912a9ea80cd604048ab);
#
#
#
#
#
#             var tile_layer_dca7d31070c2476bf6a12e2c7474a488 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e57dbf1d6062c912a9ea80cd604048ab);
#
#
#         function geo_json_2b4d527d52aef64192c357a53efa52b7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 0.16629883492694078};
#             }
#         }
#
#         function geo_json_2b4d527d52aef64192c357a53efa52b7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2b4d527d52aef64192c357a53efa52b7 = L.geoJson(null, {
#                 onEachFeature: geo_json_2b4d527d52aef64192c357a53efa52b7_onEachFeature,
#
#                 style: geo_json_2b4d527d52aef64192c357a53efa52b7_styler,
#         });
#
#         function geo_json_2b4d527d52aef64192c357a53efa52b7_add (data) {
#             geo_json_2b4d527d52aef64192c357a53efa52b7
#                 .addData(data)
#                 .addTo(map_e57dbf1d6062c912a9ea80cd604048ab);
#         }
#             geo_json_2b4d527d52aef64192c357a53efa52b7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-73.973506, 42.600164], [-73.852926, 40.849097]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_ecab1f099913fddf2f1f267c23933ef2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 0.400500629823145};
#             }
#         }
#
#         function geo_json_ecab1f099913fddf2f1f267c23933ef2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ecab1f099913fddf2f1f267c23933ef2 = L.geoJson(null, {
#                 onEachFeature: geo_json_ecab1f099913fddf2f1f267c23933ef2_onEachFeature,
#
#                 style: geo_json_ecab1f099913fddf2f1f267c23933ef2_styler,
#         });
#
#         function geo_json_ecab1f099913fddf2f1f267c23933ef2_add (data) {
#             geo_json_ecab1f099913fddf2f1f267c23933ef2
#                 .addData(data)
#                 .addTo(map_e57dbf1d6062c912a9ea80cd604048ab);
#         }
#             geo_json_ecab1f099913fddf2f1f267c23933ef2_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-73.973506, 42.600164], [-75.81962, 42.160117]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_6a14c188121153714b743ee385f1e0d4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 0.24666103359818992};
#             }
#         }
#
#         function geo_json_6a14c188121153714b743ee385f1e0d4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6a14c188121153714b743ee385f1e0d4 = L.geoJson(null, {
#                 onEachFeature: geo_json_6a14c188121153714b743ee385f1e0d4_onEachFeature,
#
#                 style: geo_json_6a14c188121153714b743ee385f1e0d4_styler,
#         });
#
#         function geo_json_6a14c188121153714b743ee385f1e0d4_add (data) {
#             geo_json_6a14c188121153714b743ee385f1e0d4
#                 .addData(data)
#                 .addTo(map_e57dbf1d6062c912a9ea80cd604048ab);
#         }
#             geo_json_6a14c188121153714b743ee385f1e0d4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-73.973506, 42.600164], [-75.611582, 42.493581]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_4818e9af039ba7dc99118265a8259151_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;opacity&quot;: 0.5, &quot;weight&quot;:
